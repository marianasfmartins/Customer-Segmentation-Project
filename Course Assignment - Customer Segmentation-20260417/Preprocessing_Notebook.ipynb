# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.impute import KNNImputer


def preprocess_data(df):
    
    df = df.copy()
    
    # --- 1. Drop unnecessary features ---
    drop_cols = [
        'customer_id',
        'customer_name',
        'loyalty_card_number',
        'birth_month',
        'birth_day',
        'latitude',
        'longitude',
        'customer_birthdate', 'customer_gender'
    ]
    df.drop(columns=[col for col in drop_cols if col in df.columns], inplace=True)
    
    # --- 2. Feature Engineering ---
    df['age'] = 2025 - df['birth_year']
    df.drop(columns=['birth_year'], inplace=True)
    
    df['total_kids'] = df['kids_home'] + df['teens_home']
    df.drop(columns=['kids_home', 'teens_home'], inplace=True)
    
    spend_cols = [col for col in df.columns if 'lifetime_spend' in col]
    df['total_lifetime_spend'] = df[spend_cols].sum(axis=1)

    # --- 3. Fix percentage_of_products_bought_promotion ---
    df.loc[df['percentage_of_products_bought_promotion'] < 0, 'percentage_of_products_bought_promotion'] = np.nan

    # --- 5. Impute missing values using KNN ---
    num_cols = df.select_dtypes(include=np.number).columns.tolist()
    imputer = KNNImputer(n_neighbors=5)
    df[num_cols] = imputer.fit_transform(df[num_cols])

    # --- 6. Log transform right-skewed features ---
    log_cols = [col for col in spend_cols if col != 'lifetime_spend_vegetables'] + ['total_lifetime_spend']
    for col in log_cols:
        if col in df.columns:
            df[col] = np.log1p(df[col])

    # --- 7. Scale all features ---
    scaler = StandardScaler()
    final_num_cols = df.select_dtypes(include=np.number).columns.tolist()
    df[final_num_cols] = scaler.fit_transform(df[final_num_cols])

    return df


df = pd.read_csv('Course Assignment - Customer Segmentation-20260417\data_eda.csv')
df_processed = preprocess_data(df)
df_processed
# Out:
# <>:56: SyntaxWarning: invalid escape sequence '\d'
# <>:56: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\maria\AppData\Local\Temp\ipykernel_25492\1104686335.py:56: SyntaxWarning: invalid escape sequence '\d'
#   df = pd.read_csv('Course Assignment - Customer Segmentation-20260417\data_eda.csv')
#        number_complaints  distinct_stores_visited  lifetime_spend_groceries  \
# 0               0.077305                -0.100209                 -0.060680
# 1              -1.047909                -0.699432                  0.121140
# 2              -0.372780                -0.699432                  0.005158
# 3               1.202519                -1.298655                 -0.587438
# 4               2.327733                -1.298655                 -0.347932
# ...                  ...                      ...                       ...
# 33033           1.202519                -1.298655                 -3.826885
# 33034           0.077305                -1.298655                 -0.448981
# 33035          -1.047909                 0.499014                 -0.506251
# 33036           0.077305                 1.697460                 -0.458217
# 33037           0.077305                -1.298655                 -1.117124
#
#        lifetime_spend_electronics  typical_hour  lifetime_spend_vegetables  \
# 0                        0.905980     -0.302185                  -0.538807
# 1                       -0.214358     -0.426458                   1.978550
# 2                       -5.172236     -0.343609                  -0.259271
# 3                       -0.115206      1.106241                  -0.982685
# 4                        1.531874      0.899120                  -0.528055
# ...                           ...           ...                        ...
# 33033                    1.689495      0.609150                  -0.819878
# 33034                    1.737103      1.727606                  -0.664751
# 33035                    0.095465      0.277755                   1.345755
# 33036                    0.631950     -0.343609                  -0.196299
# 33037                    0.357003     -1.172095                  -0.035028
#
#        lifetime_spend_nonalcohol_drinks  lifetime_spend_alcohol_drinks  \
# 0                             -0.205715                      -0.757472
# 1                              0.483316                      -1.329239
# 2                             -1.799547                      -1.130350
# 3                              0.966370                       0.957290
# 4                              0.627836                       0.535346
# ...                                 ...                            ...
# 33033                          0.582928                       0.836198
# 33034                          0.387066                       1.164256
# 33035                          0.378734                      -1.138165
# 33036                         -0.293580                       0.458860
# 33037                          0.042870                      -1.070099
#
#        lifetime_spend_meat  lifetime_spend_fish  lifetime_spend_hygiene  \
# 0                -2.364362            -0.425286               -0.027372
# 1                -2.011574            -2.511578                1.166886
# 2                 0.831274            -0.226461               -0.110173
# 3                 0.608518             0.879909               -0.153363
# 4                 0.688144             0.827792               -0.630515
# ...                    ...                  ...                     ...
# 33033             0.649267             0.930946               -2.146466
# 33034             0.869181             0.408093               -0.922134
# 33035            -0.364887            -1.459069                1.079595
# 33036             0.092189            -0.931921               -0.316879
# 33037             0.460644             0.561849                0.830205
#
#        lifetime_spend_videogames  lifetime_spend_petfood  \
# 0                       0.162888                0.435642
# 1                       0.398554                1.261281
# 2                      -0.668127               -0.387022
# 3                       1.838840               -0.668463
# 4                       1.591820                0.643641
# ...                          ...                     ...
# 33033                   1.806799                0.363508
# 33034                   2.054468               -0.353617
# 33035                  -0.780682               -0.161563
# 33036                   0.733988               -0.366890
# 33037                   0.371219               -0.276343
#
#        lifetime_total_distinct_products  \
# 0                              0.378445
# 1                             -0.178573
# 2                             -0.641180
# 3                             -0.537330
# 4                             -1.349253
# ...                                 ...
# 33033                          0.123538
# 33034                         -0.490125
# 33035                          0.538941
# 33036                          2.228875
# 33037                         -0.442920
#
#        percentage_of_products_bought_promotion  year_first_transaction  \
# 0                                     1.079816                0.931644
# 1                                    -0.741736               -0.459419
# 2                                    -1.047143               -2.049206
# 3                                    -0.349528                1.130368
# 4                                    -0.603038                1.130368
# ...                                        ...                     ...
# 33033                                -0.320250               -0.260696
# 33034                                -0.765978               -0.260696
# 33035                                -0.620627               -0.658143
# 33036                                 1.744064                0.335474
# 33037                                -0.353485                0.335474
#
#             age  total_kids  total_lifetime_spend
# 0      0.048688   -0.008692             -0.183430
# 1     -0.228612   -0.571518             -0.024482
# 2     -0.006772   -1.134345             -0.518676
# 3     -0.616832   -1.134345             -0.592154
# 4      0.104148   -1.134345              0.431477
# ...         ...         ...                   ...
# 33033 -0.117692   -1.134345             -0.053743
# 33034  0.880587   -0.571518              0.684492
# 33035  1.435187   -0.008692             -0.703196
# 33036  1.102427   -0.008692             -0.744531
# 33037 -1.060511   -0.571518             -1.076168
#
# [33038 rows x 19 columns]
